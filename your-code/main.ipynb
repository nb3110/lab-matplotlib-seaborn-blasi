# %% [markdown]
# # Lab | Matplotlib & Seaborn
#
# #### Import all the necessary libraries here:

# %%
# Libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# Your Code Here

# %% [markdown]
# ## Challenge
# #### Import the `Fitbit2` dataset and store it in a variable called `fitbit`. You can find the dataset in Ironhack's database:
# * db: `fitbit`
# * table: `fitbit2`

# %%
pwd
# Out:
# 'C:\\Users\\Sofia\\Desktop\\IRONHACK_bootcamp\\lab-matplotlib-seaborn-blasi\\your-code'

# %%
# your code here
#pd.read_csv(r"C:\Users\Sofia\Desktop\IRONHACK_bootcamp\lab-matplotlib-seaborn-blasi\data\Fitbit2.csv")
df = pd.read_csv("..\data\Fitbit2.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 367 entries, 0 to 366
# Data columns (total 24 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Date                        367 non-null    object
#  1   Calorie burned              367 non-null    int64
#  2   Steps                       367 non-null    int64
#  3   Distance                    367 non-null    float64
#  4   Floors                      367 non-null    int64
#  5   Minutes Sedentary           367 non-null    float64
#  6   Minutes Lightly Active      367 non-null    int64
#  7   Minutes Fairly Active       367 non-null    int64
#  8   Minutes Very Active         367 non-null    int64
#  9   Activity Calories           367 non-null    int64
#  10  MinutesOfSleep              367 non-null    int64
#  11  MinutesOfBeingAwake         367 non-null    int64
#  12  NumberOfAwakings            367 non-null    int64
# ...

# %% [markdown]
# #### From the Fitbit data, we want to visually understand:
#
# How the average number of steps change by month. Use the appropriate visualization to show the median steps by month. Is Fitbitter more active on weekend or workdays?
# **Hints**:
#
# * Use Months_encoded and Week_or Weekend columns.
# * Set your size figure to 12,4
# * Explore plt.sca
# * Explore plt.xticks
# * Save your figures in a folder called `figures` in your repo.

# %%
# AVERAGE STEPS BY MONTH_ENCODED
# your code here

#aux = df.groupby("Months_encoded")["Steps"].mean()

sns.barplot(x=df["Months_encoded"], y=df["Steps"], palette="magma", estimator = "mean", errorbar = None); #maya

# %%
# AVERAGE STEPS BY WORK_OR_WEEKEND
sns.barplot(x=df["Work_or_Weekend"], y=df["Steps"], palette="magma", estimator = "mean", errorbar = None); #maya

# %% [markdown]
# #### Write a loop to plot 3 scatter plots of the following features:
#
# * Minutes Lightly Active vs Steps
# * Minutes Very Active vs Steps
# * Minutes Sedentary vs Steps

# %%
var_list = ["Minutes Lightly Active","Minutes Very Active","Minutes Sedentary" ]

for  i in var_list:
    sns.scatterplot(data=df, x=i, y="Steps")
    plt.show()

# %% [markdown]
# ## Challenge
#
# #### Import the `titanic` dataset and store it in a variable called `titanic`. You can find the dataset in Ironhack's database:
# * db: `titanic`
# * table: `titanic`

# %%
# your code here
titanic = pd.read_csv(r"..\data\titanic.csv")

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500    U0        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250    U0        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500    U0        S

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes.

# %%
# your code here
df_types = pd.DataFrame(titanic.dtypes.sort_values(), columns=["types"])
df_types
# Out:
#                types
# PassengerId    int64
# Pclass         int64
# SibSp          int64
# Parch          int64
# Survived     float64
# Age          float64
# Fare         float64
# Name          object
# Gender        object
# Ticket        object
# Cabin         object
# Embarked      object

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# **Hint**: Use Pandas select_dtypes.

# %%
# NUMERICAL VARIABLES
df_types[~(df_types["types"]=="object")]
# Out:
#                types
# PassengerId    int64
# Pclass         int64
# SibSp          int64
# Parch          int64
# Survived     float64
# Age          float64
# Fare         float64

# %%
# CATEGORICAL VARIABLES
df_types[(df_types["types"]=="object")]
# Out:
#            types
# Name      object
# Gender    object
# Ticket    object
# Cabin     object
# Embarked  object

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6).
# **Hint**: To set the style you can use matplotlib or seaborn functions. Do some research on the matter.

# %%
# your code here
plt.style.use('classic')
sns.set(rc={'figure.figsize':(12,6)})

# %% [markdown]
# #### Use the right visulalization to show the distribution of column `Age`.

# %%
plt.hist(titanic["Age"], density=True, bins=30)  # density=False would make counts
plt.ylabel('Prob')
plt.xlabel('Data');

# %% [markdown]
# #### Use subplots and plot the distribution of the `Age`  with bins equal to 10, 20 and 50.

# %%
plt.hist(titanic["Age"], density=True, bins=[10,20,50])  # density=False would make counts
plt.ylabel('Prob')
plt.xlabel('Data');

# %% [markdown]
# #### How does the bin size affect your plot?

# %%
"""
having an appropiate amount of bins gives you relevant information about the distribution of Age in the sample. 
having only 3 bins makes the plot worthless

"""

# %% [markdown]
# #### Use seaborn to show the distribution of column `Age`.

# %%
# your code here
sns.histplot(data=titanic, x="Age")
# Out:
# <AxesSubplot: xlabel='Age', ylabel='Count'>

# %% [markdown]
# #### Use the right plot to visualize column `Gender`. There are 2 ways of doing it. Do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
plt.bar(titanic["Gender"].unique(),titanic[["Gender"]].value_counts())
plt.show()

# %%
sns.countplot(x=titanic["Gender"])
# Out:
# <AxesSubplot: xlabel='Gender', ylabel='count'>

# %%
# Method 2 - seaborn
sns.barplot(x=titanic["Gender"].unique(), y=titanic["Gender"].value_counts(), palette="magma", estimator = "sum", errorbar = None); #maya

# %% [markdown]
# #### Use the right plot to visualize the column `Pclass`.

# %%
# your code here
sns.countplot(x=titanic["Pclass"])
# Out:
# <AxesSubplot: xlabel='Pclass', ylabel='count'>

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. What kind of plot would you use? Plot it.

# %%
# your code 
titanic["Age"].describe()
# Out:
# count    1309.000000
# mean       29.879186
# std        13.448335
# min         0.170000
# 25%        22.000000
# 50%        28.500000
# 75%        37.000000
# max        80.000000
# Name: Age, dtype: float64

# %%
sns.boxplot(x=titanic["Age"])
# Out:
# <AxesSubplot: xlabel='Age'>

# %% [markdown]
# ![image.png](attachment:f1dc8fa7-2af9-411e-8b97-7395238a7da5.png)

# %% [markdown]
# #### What does the last plot tell you about the feature `Age`?

# %%
"""
#the distribution has slight positive skew (more young people), with outliers maily on the upper side of the distribution."""

# %% [markdown]
# #### Now in addition to the summary statistics, we want to have in the same plot the distribution of `Age`. What kind of plot would you use? Plot it.

# %%
# your code here

# %% [markdown]
# #### What additional information does the last plot provide about feature `Age`?

# %%
"""
your comments here
"""

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
plt.scatter(titanic["Age"], titanic["Fare"])
plt.show()

# %%
# Method 2 - seaborn
sns.scatterplot(data=titanic, x="Age", y="Fare")
# Out:
# <AxesSubplot: xlabel='Age', ylabel='Fare'>

# %% [markdown]
# #### Plot the correlation matrix using seaborn.

# %%
# your code here
sns.heatmap(titanic.corr());
# Out:
# C:\Users\Sofia\AppData\Local\Temp\ipykernel_4288\3073385489.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(titanic.corr());

# %% [markdown]
# #### What are the most correlated features?

# %%
"""
your comments here

SibSp - Parch
Survived - 
"""

# %% [markdown]
# #### Use the most appropriate plot to display the summary statistics of `Age` depending on `Pclass`.

# %%
# your code here
sns.boxplot(x=titanic["Pclass"],y=titanic["Age"])
# Out:
# <AxesSubplot: xlabel='Pclass', ylabel='Age'>

# %% [markdown]
# #### Use seaborn to plot the distribution of `Age` based on the `Gender`.
# **Hint**: Use Facetgrid.

# %%
# your code here
############# Main Section         #############
# Form a facetgrid using columns with a hue
graph = sns.FacetGrid(titanic, col = "Gender")
# map the above form facetgrid with some attributes
graph.map(sns.histplot, "Age")
# show the object
plt.show()
